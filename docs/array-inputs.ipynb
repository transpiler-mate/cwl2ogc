# %% [markdown]
# # Array Inputs
#
# Array Inputs refers to the [2.4.2. Array Inputs](https://www.commonwl.org/user_guide/topics/inputs.html#array-inputs) paragraph of the _2.4. Inputs_ chapter of the [Common Workflow Language User Guide](https://www.commonwl.org/user_guide/index.html#)

# %% [markdown]
# ## 1. Parsing
#
# In this sample we'll show the access from a remote public URL.

# %%
from cwl_loader import load_cwl_from_location
from cwl2ogc import BaseCWLtypes2OGCConverter

cwl_document = load_cwl_from_location(
    "https://raw.githubusercontent.com/transpiler-mate/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/array-inputs.cwl"
)
cwl_converter = BaseCWLtypes2OGCConverter(cwl_document)
# Out:
# 2025-11-06 23:44:41.967 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/transpiler-mate/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/array-inputs.cwl...
# 2025-11-06 23:44:42.500 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/transpiler-mate/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/array-inputs.cwl...
# 2025-11-06 23:44:42.506 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-11-06 23:44:42.506 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - No needs to update the Raw CWL document since it targets already the v1.2
# 2025-11-06 23:44:42.506 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-11-06 23:44:42.822 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-11-06 23:44:42.823 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-11-06 23:44:42.823 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-11-06 23:44:42.824 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-11-06 23:44:42.824 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-11-06 23:44:42.824 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-11-06 23:44:42.824 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-11-06 23:44:42.824 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/transpiler-mate/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/array-inputs.cwl successfully load!

# %% [markdown]
# # 2. Inputs conversion
#
# Once the document is parsed, invoke the `cwl2ogc` APIs to convert the CWL inputs to the OGC JSON format:

# %%
import sys

cwl_converter.dump_inputs(stream=sys.stdout, pretty_print=True)
# Out:
# {
#   "filesA": {
#     "schema": {
#       "type": "array",
#       "items": {
#         "type": "string"
#       }
#     },
#     "metadata": [
#       {
#         "title": "cwl:type",
#         "value": "string[]"
#       }
#     ],
#     "minOccurs": 1,
#     "maxOccurs": 1,
#     "valuePassing": "byValue",
#     "title": "filesA label",
#     "description": "filesA doc"
#   },
#   "filesB": {
#     "schema": {
#       "type": "array",
#       "items": {
#         "type": "string"
#       }
#     },
#     "metadata": [
#       {
#         "title": "cwl:type",
#         "value": "string[]"
#       }
#     ],
#     "minOccurs": 1,
#     "maxOccurs": 1,
#     "valuePassing": "byValue",
#     "title": "filesB label",
#     "description": "filesB doc"
#   },
#   "filesC": {
#     "schema": {
#       "type": "array",
#       "items": {
#         "type": "string"
#       }
#     },
#     "metadata": [
#       {
#         "title": "cwl:type",
#         "value": "string[]"
#       }
#     ],
#     "minOccurs": 1,
#     "maxOccurs": 1,
#     "valuePassing": "byValue",
#     "title": "filesC label",
#     "description": "filesC doc"
#   }
# }

# %% [markdown]
# # 3. Outputs conversion
#
# Users can reuse the `BaseCWLtypes2OGCConverter` instance to convert the CWL outputs to the OGC JSON format:

# %%
cwl_converter.dump_outputs(stream=sys.stdout, pretty_print=True)
# Out:
# {
#   "example_out": {
#     "schema": {
#       "type": "string"
#     },
#     "metadata": [
#       {
#         "title": "cwl:type",
#         "value": "stdout"
#       }
#     ]
#   }
# }
